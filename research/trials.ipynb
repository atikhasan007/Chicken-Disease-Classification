# %%
print("hello")
# Out:
# hello

# %%
import yaml

yaml_file_path = "test.yaml"

with open(yaml_file_path, 'r') as f:
    data = yaml.safe_load(f)

# %%
print(data)
# Out:
# {'name': 'Atik', 'age': 23, 'city': 'Dhaka', 'country': 'Bangladesh'}

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
data['name']
# Out:
# 'Atik'

# %%
# configbox usd kore dictionary ke ei fomat print kora jay

from box import ConfigBox

d = ConfigBox(data)

# %%
d
# Out:
# ConfigBox({'name': 'Atik', 'age': 23, 'city': 'Dhaka', 'country': 'Bangladesh'})

# %%
d.name
# Out:
# 'Atik'

# %%
d.age
# Out:
# 23

# %% [markdown]
# Ensure_annotations

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x=2, y="4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x=2, y="4")  # error asbe robbast cost likte hobe
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 get_product(x=2, y="4")  # error asbe robbast cost likte hobe
#
# File c:\Users\Hp\anaconda3\envs\cnncls\lib\site-packages\ensure\main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001EC33F4A550> does not match annotation type <class 'int'>

# %% [markdown]
# Google drive

# %%
import gdown

file_id = "1d_TPOi0PY6tngaVhMpzDdVaG6Vo1FAg1"

url = f"https://drive.google.com/uc?id={file_id}"

output = "data.zip"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1d_TPOi0PY6tngaVhMpzDdVaG6Vo1FAg1
# To: c:\Users\Hp\Desktop\Chicken-Disease-Classification\research\data.zip
# 100%|██████████| 11.6M/11.6M [00:01<00:00, 9.06MB/s]
# 'data.zip'

# %%
import zipfile

with zipfile.ZipFile("data.zip", 'r') as zip_ref:
    zip_ref.extractall("data")

print("Extraction done")
# Out:
# Extraction done

# %%
# Out:
# ['Chicken-fecal-images']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# %%
img_path = r"C:\Users\Hp\Desktop\Chicken-Disease-Classification\research\data\Chicken-fecal-images\Coccidiosis\cocci.192.jpg"

img = mpimg.imread(img_path)

plt.imshow(img)
plt.title("Coccidiosis")
plt.axis("off")
plt.show()

# %%
img_path = r"C:\Users\Hp\Desktop\Chicken-Disease-Classification\research\data\Chicken-fecal-images\Healthy\healthy.0.jpg"

img = mpimg.imread(img_path)

plt.imshow(img)
plt.title("Healthy")
plt.axis("off")
plt.show()
